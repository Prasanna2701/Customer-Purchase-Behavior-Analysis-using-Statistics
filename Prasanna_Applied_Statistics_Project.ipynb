# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##### **Name**            - Prasanna Daulatkar

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Prasanna2701/Customer-Purchase-Behavior-Analysis-using-Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset First Look
df = pd.read_csv('/content/drive/MyDrive/Capstone Project/Applied Statstics/Superstore Marketing Data - Sheet1.csv')
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
df.shape
# Out:
# (2240, 22)

# %%
#Detailed information of the play store data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
#Check, how many null value in each column
missing_values = df.isnull().sum()
missing_values
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
# check for duplicate values in dataset
len(df[df.duplicated()])
# Out:
# 0

# %%
mean_income = df['Income'].mean()  # Calculate the mean of the 'Income' column
df['Income'].fillna(mean_income, inplace=True)  # Fill missing values with the mean

# %%
print("Cleaned and Preprocessed Dataset:")
print(df.head())

df.to_csv("cleaned_dataset.csv", index=False)
# Out:
# Cleaned and Preprocessed Dataset:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
# Display the summary statistics DataFrame
summary_stats = df.describe()
summary_stats
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2240.000000  2240.000000    2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804   52247.251354     0.444196     0.506250
# std     3246.662198    11.984069   25037.797168     0.538398     0.544538
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000   35538.750000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51741.500000     0.000000     0.000000
# 75%     8427.750000  1977.000000   68289.750000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2240.000000  2240.000000  2240.000000      2240.000000
# mean     49.109375   303.935714    26.302232       166.950000
# std      28.962453   336.597393    39.773434       225.715373
# ...

# %%
#showing distribution of age
plt.figure(figsize=(8, 6))
sns.histplot(df['Year_Birth'], bins=30, kde=True, color='coral')
plt.title('Age Distribution', fontsize=14)
plt.xlabel('Year of Birth', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
#showing distribution of education
plt.figure(figsize=(8, 6))
sns.countplot(x='Education', data=df, palette="viridis")
plt.title('Distribution of Education', fontsize=14)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-53-692cf1bd235e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Education', data=df, palette="viridis")  # Add a color palette

# %%
#showing distribution of income
plt.figure(figsize=(8, 6))
sns.histplot(df['Income'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Income', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
#showing distribution of marital status
plt.figure(figsize=(8, 6))
sns.countplot(x='Marital_Status', data=df, palette="Set3")
plt.title('Distribution of Marital Status', fontsize=14)
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# <ipython-input-51-0b07c87d5e81>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Marital_Status', data=df, palette="Set3")  # Add a color palette

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
# Lets first calculate measures of central tendency (mean, median, mode)
# 1 : Mean
key_variables = ['Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
                 'MntFishProducts', 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumWebVisitsMonth']

means = df[key_variables].mean()

print('Means of selected variables in the dataset:')
for variable, mean_val in means.items():
    print(f"  {variable}: {mean_val:.2f}")
# Out:
# Means of selected variables in the dataset:
#   Income: 52247.25
#   Recency: 49.11
#   MntWines: 303.94
#   MntFruits: 26.30
#   MntMeatProducts: 166.95
#   MntFishProducts: 37.53
#   NumDealsPurchases: 2.33
#   MntGoldProds: 44.02
#   NumWebPurchases: 4.08
#   NumWebVisitsMonth: 5.32

# %%
# 2 : Median
key_variables = ['Income', 'Recency', 'Kidhome', 'Teenhome', 'MntWines', 'MntFruits',
                 'MntMeatProducts', 'MntFishProducts', 'NumDealsPurchases', 'NumWebPurchases', 'NumWebVisitsMonth']

medians = df[key_variables].median()

print('Medians of key variables in the dataset:')
for variable, median_val in medians.items():
    print(f"  {variable}: {median_val:.2f}")
# Out:
# Medians of key variables in the dataset:
#   Income: 51741.50
#   Recency: 49.00
#   Kidhome: 0.00
#   Teenhome: 0.00
#   MntWines: 173.50
#   MntFruits: 8.00
#   MntMeatProducts: 67.00
#   MntFishProducts: 12.00
#   NumDealsPurchases: 2.00
#   NumWebPurchases: 4.00
#   NumWebVisitsMonth: 6.00

# %%
# 3 : Mode
key_variables = ['Income', 'Recency', 'Kidhome', 'Teenhome', 'MntWines', 'MntFruits',
                 'MntMeatProducts', 'MntFishProducts', 'NumDealsPurchases', 'NumWebPurchases', 'NumWebVisitsMonth']

print('Modes of key variables in the dataset:')
for variable in key_variables:
    mode_values = df[variable].mode()
    print(f"  {variable}:")
    for mode_value in mode_values:
        print(f"    - {mode_value}")
# Out:
# Modes of key variables in the dataset:
#   Income:
#     - 52247.25135379061
#   Recency:
#     - 56
#   Kidhome:
#     - 0
#   Teenhome:
#     - 0
#   MntWines:
#     - 2
#   MntFruits:
#     - 0
#   MntMeatProducts:
#     - 7
#   MntFishProducts:
#     - 0
#   NumDealsPurchases:
#     - 1
#   NumWebPurchases:
#     - 2
#   NumWebVisitsMonth:
#     - 7

# %% [markdown]
# # Measures of dispersion (variance, standard deviation) for key variables:

# %%
# 4 : Variance
key_variables = ['Income','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
variances = df[key_variables].var()

print('Variances of key variables in the dataset:')
for variable, var in variances.items():
    print(f"  {variable}: {var:.2f}")
# Out:
# Variances of key variables in the dataset:
#   Income: 626891287.05
#   Recency: 838.82
#   Kidhome: 0.29
#   Teenhome: 0.30
#   MntWines: 113297.80
#   MntFruits: 1581.93
#   MntMeatProducts: 50947.43
#   MntFishProducts: 2984.33
#   NumDealsPurchases: 3.73
#   NumWebPurchases: 7.72
#   NumWebVisitsMonth: 5.89

# %%
# 5 : Standard Deviation
key_variables = ['Income','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
standard_deviations = df[key_variables].std()

print('Standard deviations of key variables in the dataset:')
for variable, std_dev in standard_deviations.items():
    print(f"  {variable}: {std_dev:.2f}")
# Out:
# Standard deviations of key variables in the dataset:
#   Income: 25037.80
#   Recency: 28.96
#   Kidhome: 0.54
#   Teenhome: 0.54
#   MntWines: 336.60
#   MntFruits: 39.77
#   MntMeatProducts: 225.72
#   MntFishProducts: 54.63
#   NumDealsPurchases: 1.93
#   NumWebPurchases: 2.78
#   NumWebVisitsMonth: 2.43

# %% [markdown]
# # Identify Outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create boxplots for key variables
key_variables = ['Income', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
                 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumWebVisitsMonth']

# Set a consistent style for all plots
sns.set_theme(style="whitegrid")

# Define a color palette
palette = sns.color_palette("muted")

for i, variable in enumerate(key_variables):
    plt.figure(figsize=(8, 6))
    sns.boxplot(y=df[variable], width=0.4, color=palette[i])
    plt.title(f'Distribution of {variable}', fontsize=14)
    plt.ylabel(variable, fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    sns.despine(left=True)

    median_val = df[variable].median()
    plt.axhline(y=median_val, color='red', linestyle='--', linewidth=1)
    plt.text(0.1, median_val + 5, f'Median: {median_val:.2f}', color='red')

    # Identify and annotate potential outliers (adjust threshold as needed)
    outlier_threshold = df[variable].quantile(0.75) + 1.5 * (df[variable].quantile(0.75) - df[variable].quantile(0.25))
    outliers = df[variable][df[variable] > outlier_threshold]
    if not outliers.empty:
        plt.scatter(x=[0]*len(outliers), y=outliers, color='red', marker='o', label='Potential Outliers')
        plt.legend()

    plt.show()
    print()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
total_purchases = df[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)
p_purchase = total_purchases.mean() / total_purchases.max()
expected_purchases = total_purchases.mean()

# %%
from scipy.stats import norm

# Calculate income statistics
mu_income, sigma_income = df['Income'].mean(), df['Income'].std()
prob_income_gt_70000 = 1 - norm.cdf(70000, mu_income, sigma_income)
expected_income = mu_income + sigma_income * norm.ppf(prob_income_gt_70000)

# Calculate purchase probability and expected number (replace with your logic)
# Example: probability of purchase if income > 50000
p_purchase = df[df['Income'] > 50000]['TotalSpend'].mean() / df['TotalSpend'].mean()
expected_purchases = p_purchase * len(df)

print("Probability Distributions and Calculated Values:")
print(f"Total Purchases:")
print(f"   Probability of a purchase: {p_purchase:.4f}")
print(f"   Expected number of purchases: {expected_purchases:.2f}")

print(f"\nIncome:")
print(f"   Probability of income > $70,000: {prob_income_gt_70000:.4f}")
print(f"   Expected income: ${expected_income:.2f}")
# Out:
# Probability Distributions and Calculated Values:
# Total Purchases:
#    Probability of a purchase: 1.3370
#    Expected number of purchases: 2994.85
#
# Income:
#    Probability of income > $70,000: 0.2392
#    Expected income: $34494.50

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
df['TotalSpend'] = df[['NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']].sum(axis=1)

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Income', y='TotalSpend', data=df, color='skyblue', alpha=0.7)
plt.title('Relationship between Income and Total Spending', fontsize=14)
plt.xlabel('Income', fontsize=12)
plt.ylabel('Total Spending', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.despine()

sns.regplot(x='Income', y='TotalSpend', data=df, scatter=False, color='red')

plt.show()

# %%
# Calculate correlation matrix
correlation_matrix = df.select_dtypes(include=['number']).corr()

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5,
            annot_kws={"size": 10})
plt.title('Correlation Matrix', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
# Education-Based Insights

plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='TotalSpend', data=df, palette="Set2")
plt.title('Spending Habits across Different Education Levels', fontsize=14)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Total Spending', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.show()
# Out:
# <ipython-input-39-845a5edbc2f2>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Education', y='TotalSpend', data=df, palette="Set2")  # Use a color palette

# %% [markdown]
# **Insight**: Customers with a 'PhD' education level exhibit higher spending on average.
#
# **Recommendation**: Tailor marketing messages and offers to appeal to customers with a higher education level.

# %%
#Marital Status-Based Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='TotalSpend', data=df, palette="pastel")
plt.title('Spending Habits across Different Marital Statuses', fontsize=14)
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Total Spending', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels if needed
plt.show()
# Out:
# <ipython-input-40-8d6897c3dfd6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Marital_Status', y='TotalSpend', data=df, palette="pastel")  # Use a color palette

# %% [markdown]
# **Insight**: Divorced & widow customers tend to have higher spending compared to other marital statuses.
#
# **Recommendation**: Develop promotions or loyalty programs targeting married customers to enhance their engagement and spending.

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍
